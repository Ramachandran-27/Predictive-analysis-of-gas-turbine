# %%
#linear Regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
# %matplotlib inline

# %%
df = pd.read_csv('data1.csv')

# %%
df.head()
# Out:
#    index  Lever position   Ship speed (v)   \
# 0      0            1.138                3
# 1      1            2.088                6
# 2      2            3.144                9
# 3      3            4.161               12
# 4      4            5.140               15
#
#    Gas Turbine (GT) shaft torque (GTT) [kN m]    \
# 0                                       289.964
# 1                                      6960.180
# 2                                      8379.229
# 3                                     14724.395
# 4                                     21636.432
#
#    GT rate of revolutions (GTn) [rpm]    \
# 0                              1349.489
# 1                              1376.166
# 2                              1386.757
# 3                              1547.465
# 4                              1924.313
#
#    Gas Generator rate of revolutions (GGn) [rpm]    \
# 0                                         6677.380
# 1                                         6828.469
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11934 entries, 0 to 11933
# Data columns (total 19 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   index                                                     11934 non-null  int64
#  1   Lever position                                            11934 non-null  float64
#  2   Ship speed (v)                                            11934 non-null  int64
#  3   Gas Turbine (GT) shaft torque (GTT) [kN m]                11934 non-null  float64
#  4   GT rate of revolutions (GTn) [rpm]                        11934 non-null  float64
#  5   Gas Generator rate of revolutions (GGn) [rpm]             11934 non-null  float64
#  6   Starboard Propeller Torque (Ts) [kN]                      11934 non-null  float64
#  7   Port Propeller Torque (Tp) [kN]                           11934 non-null  float64
# ...

# %%
df.describe()
# Out:
#               index  Lever position   Ship speed (v)   \
# count  11934.000000     11934.000000     11934.000000
# mean    5966.500000         5.166667        15.000000
# std     3445.193391         2.626388         7.746291
# min        0.000000         1.138000         3.000000
# 25%     2983.250000         3.144000         9.000000
# 50%     5966.500000         5.140000        15.000000
# 75%     8949.750000         7.148000        21.000000
# max    11933.000000         9.300000        27.000000
#
#        Gas Turbine (GT) shaft torque (GTT) [kN m]    \
# count                                  11934.000000
# mean                                   27247.498685
# std                                    22148.613155
# min                                      253.547000
# 25%                                     8375.883750
# 50%                                    21630.659000
# 75%                                    39001.426750
# max                                    72784.872000
#
# ...

# %%
df['GT Compressor inlet air temperature (T1) [C]\xa0 '].value_counts()
# Out:
# GT Compressor inlet air temperature (T1) [C]
# 288    11934
# Name: count, dtype: int64

# %%
nv = df.drop(['GT Compressor inlet air temperature (T1) [C]\xa0 ','GT Compressor inlet air pressure (P1) [bar]\xa0 '],axis=1)

# %%
nv.head()
# Out:
#    index  Lever position   Ship speed (v)   \
# 0      0            1.138                3
# 1      1            2.088                6
# 2      2            3.144                9
# 3      3            4.161               12
# 4      4            5.140               15
#
#    Gas Turbine (GT) shaft torque (GTT) [kN m]    \
# 0                                       289.964
# 1                                      6960.180
# 2                                      8379.229
# 3                                     14724.395
# 4                                     21636.432
#
#    GT rate of revolutions (GTn) [rpm]    \
# 0                              1349.489
# 1                              1376.166
# 2                              1386.757
# 3                              1547.465
# 4                              1924.313
#
#    Gas Generator rate of revolutions (GGn) [rpm]    \
# 0                                         6677.380
# 1                                         6828.469
# ...

# %%
fig, ax = plt.subplots(figsize = (24,11))
title = 'Correlation Heatmap of the Naval Vessel Condition'
plt.title(title,fontsize = 25)
mask = np.triu(np.ones_like(nv.corr()))
sns.heatmap(nv.corr(), cbar = True, cmap = 'icefire', annot = True, linewidth = 1, ax = ax, mask = mask)
plt.show()

# %%
ns = pd.read_excel('naval1.xlsx')

# %%
ns.head()
# Out:
#    index  Lever position  Ship speed (v)        GTT       GTn       GGn  \
# 0      0           1.138               3    289.964  1349.489  6677.380
# 1      1           2.088               6   6960.180  1376.166  6828.469
# 2      2           3.144               9   8379.229  1386.757  7111.811
# 3      3           4.161              12  14724.395  1547.465  7792.630
# 4      4           5.140              15  21636.432  1924.313  8494.777
#
#         Ts       Tp       HP   T1       T2    P48     P1      P2   Pexh  \
# 0    7.584    7.584  464.006  288  550.563  1.096  0.998   5.947  1.019
# 1   28.204   28.204  635.401  288  581.658  1.331  0.998   7.282  1.019
# 2   60.358   60.358  606.002  288  587.587  1.389  0.998   7.574  1.020
# 3  113.774  113.774  661.471  288  613.851  1.658  0.998   9.007  1.022
# 4  175.306  175.306  731.494  288  645.642  2.078  0.998  11.197  1.026
#
#       TIC     mf  Compressor DSC  Turbine DSC
# 0   7.137  0.082            0.95        0.975
# ...

# %%
ns = ns.drop(['T1','P1'], axis = 1)
ns.head()
# Out:
#    index  Lever position  Ship speed (v)        GTT       GTn       GGn  \
# 0      0           1.138               3    289.964  1349.489  6677.380
# 1      1           2.088               6   6960.180  1376.166  6828.469
# 2      2           3.144               9   8379.229  1386.757  7111.811
# 3      3           4.161              12  14724.395  1547.465  7792.630
# 4      4           5.140              15  21636.432  1924.313  8494.777
#
#         Ts       Tp       HP       T2    P48      P2   Pexh     TIC     mf  \
# 0    7.584    7.584  464.006  550.563  1.096   5.947  1.019   7.137  0.082
# 1   28.204   28.204  635.401  581.658  1.331   7.282  1.019  10.655  0.287
# 2   60.358   60.358  606.002  587.587  1.389   7.574  1.020  13.086  0.259
# 3  113.774  113.774  661.471  613.851  1.658   9.007  1.022  18.109  0.358
# 4  175.306  175.306  731.494  645.642  2.078  11.197  1.026  26.373  0.522
#
#    Compressor DSC  Turbine DSC
# 0            0.95        0.975
# ...

# %%
# Defining features and labels
X = ns.drop(['Compressor DSC','Turbine DSC','index'],axis=1)

y = ns['Compressor DSC']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 101)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred = lm.predict(X_test)

# %%
print('Coeffiecients: \n',lm.coef_)
# Out:
# Coeffiecients:
#  [ 2.60014335e-01 -7.62369632e-02 -3.19526121e-07 -2.92740638e-05
#   3.13801818e-05 -5.61710612e-04 -5.61710613e-04 -5.05978578e-06
#  -3.39085210e-03  1.84406031e-01  1.41633312e-02  7.84900768e-01
#  -7.25691673e-04  2.22244383e-01]

# %%
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#                  Coeffecient
# Lever position  2.600143e-01
# Ship speed (v) -7.623696e-02
# GTT            -3.195261e-07
# GTn            -2.927406e-05
# GGn             3.138018e-05
# Ts             -5.617106e-04
# Tp             -5.617106e-04
# HP             -5.059786e-06
# T2             -3.390852e-03
# P48             1.844060e-01
# P2              1.416333e-02
# Pexh            7.849008e-01
# TIC            -7.256917e-04
# mf              2.222444e-01

# %%
from sklearn import metrics

# %%
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
print('R2 score:', metrics.r2_score(y_test, pred))
# Out:
# RMSE: 0.005777053365883895
# R2 score: 0.8454340416549996

# %%
sns.set_style('darkgrid')
plt.scatter(y_test,pred,c='purple')
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')

x_values = [0.95,1.0]
y_values = [0.95,1.0]
plt.plot(x_values, y_values, color='black', linestyle='--')

plt.show()
#Text(0, 0.5, 'Predicted Y')

# %%
import statsmodels.api as sm

# %%
def linear_Regression(x,y):

    x = sm.add_constant(x)
    sm_model = sm.OLS(y,x).fit()
    print(sm_model.summary())

# %%
linear_Regression(X,y)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Compressor DSC   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.843
# Method:                 Least Squares   F-statistic:                     4925.
# Date:                Sat, 13 Apr 2024   Prob (F-statistic):               0.00
# Time:                        03:39:47   Log-Likelihood:                 44460.
# No. Observations:               11934   AIC:                        -8.889e+04
# Df Residuals:                   11920   BIC:                        -8.879e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              1.5381      0.188      8.201      0.000       1.171       1.906
# ...

# %%
X.head()
# Out:
#    Lever position  Ship speed (v)        GTT       GTn       GGn       Ts  \
# 0           1.138               3    289.964  1349.489  6677.380    7.584
# 1           2.088               6   6960.180  1376.166  6828.469   28.204
# 2           3.144               9   8379.229  1386.757  7111.811   60.358
# 3           4.161              12  14724.395  1547.465  7792.630  113.774
# 4           5.140              15  21636.432  1924.313  8494.777  175.306
#
#         Tp       HP       T2    P48      P2   Pexh     TIC     mf
# 0    7.584  464.006  550.563  1.096   5.947  1.019   7.137  0.082
# 1   28.204  635.401  581.658  1.331   7.282  1.019  10.655  0.287
# 2   60.358  606.002  587.587  1.389   7.574  1.020  13.086  0.259
# 3  113.774  661.471  613.851  1.658   9.007  1.022  18.109  0.358
# 4  175.306  731.494  645.642  2.078  11.197  1.026  26.373  0.522

# %%
X = X.drop(['GTT','HP'], axis = 1)

# %%
linear_Regression(X,y)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Compressor DSC   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.843
# Method:                 Least Squares   F-statistic:                     5818.
# Date:                Sat, 13 Apr 2024   Prob (F-statistic):               0.00
# Time:                        03:39:47   Log-Likelihood:                 44458.
# No. Observations:               11934   AIC:                        -8.889e+04
# Df Residuals:                   11922   BIC:                        -8.880e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              1.5610      0.186      8.401      0.000       1.197       1.925
# ...

# %%
X.head()
# Out:
#    Lever position  Ship speed (v)       GTn       GGn       Ts       Tp  \
# 0           1.138               3  1349.489  6677.380    7.584    7.584
# 1           2.088               6  1376.166  6828.469   28.204   28.204
# 2           3.144               9  1386.757  7111.811   60.358   60.358
# 3           4.161              12  1547.465  7792.630  113.774  113.774
# 4           5.140              15  1924.313  8494.777  175.306  175.306
#
#         T2    P48      P2   Pexh     TIC     mf
# 0  550.563  1.096   5.947  1.019   7.137  0.082
# 1  581.658  1.331   7.282  1.019  10.655  0.287
# 2  587.587  1.389   7.574  1.020  13.086  0.259
# 3  613.851  1.658   9.007  1.022  18.109  0.358
# 4  645.642  2.078  11.197  1.026  26.373  0.522

# %%
# @title Lever position

from matplotlib import pyplot as plt
X['Lever position'].plot(kind='hist', bins=20, title='Lever position')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
aa = X['Ship speed (v)']*X['Lever position']
bb = X['Tp']*X['Ts']
cc = X['P48']*X['GTn']
dd = X['P48']*X['Ts']
ee = X['P48']*X['Tp']
ff = X['P2']*X['Ts']
gg = X['P2']*X['Tp']
hh = X['P2']*X['GTn']
ii = X['P2']*X['P48']
jj = X['Pexh']*X['Tp']
kk = X['Pexh']*X['Ts']
ll = X['Pexh']*X['P48']
mm = X['Pexh']*X['P2']

# %%
interaction = pd.concat([X,aa,bb,cc,dd,ee,ff,gg,hh,ii,jj,ll,mm,kk],axis=1)
interaction = interaction.rename(columns = {0:'aa',1:'bb',2:'cc',3:'dd',4:'ee',5:'ff',6:'gg',7:'hh',8:'ii',9:'jj',
                                            10:'ll',11:'mm',12:'kk'})

interaction.head()
# Out:
#    Lever position  Ship speed (v)       GTn       GGn       Ts       Tp  \
# 0           1.138               3  1349.489  6677.380    7.584    7.584
# 1           2.088               6  1376.166  6828.469   28.204   28.204
# 2           3.144               9  1386.757  7111.811   60.358   60.358
# 3           4.161              12  1547.465  7792.630  113.774  113.774
# 4           5.140              15  1924.313  8494.777  175.306  175.306
#
#         T2    P48      P2   Pexh  ...          dd          ee           ff  \
# 0  550.563  1.096   5.947  1.019  ...    8.312064    8.312064    45.102048
# 1  581.658  1.331   7.282  1.019  ...   37.539524   37.539524   205.381528
# 2  587.587  1.389   7.574  1.020  ...   83.837262   83.837262   457.151492
# 3  613.851  1.658   9.007  1.022  ...  188.637292  188.637292  1024.762418
# 4  645.642  2.078  11.197  1.026  ...  364.285868  364.285868  1962.901282
#
#             gg            hh         ii          jj        ll         mm  \
# ...

# %%
linear_Regression(interaction,y)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Compressor DSC   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.934
# Method:                 Least Squares   F-statistic:                     8108.
# Date:                Sat, 13 Apr 2024   Prob (F-statistic):               0.00
# Time:                        03:39:48   Log-Likelihood:                 49686.
# No. Observations:               11934   AIC:                        -9.933e+04
# Df Residuals:                   11912   BIC:                        -9.916e+04
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -4.0715      1.368     -2.977      0.003      -6.753      -1.390
# ...

# %%
#model 2
X = ns.drop(['Compressor DSC','Turbine DSC','index'],axis=1)

y = ns['Turbine DSC']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lt = LinearRegression()

# %%
lt.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
preds = lt.predict(X_test)

# %%
print('Coeffiecients: \n',lt.coef_)
# Out:
# Coeffiecients:
#  [ 1.72268258e-03  5.67040755e-03  1.38385369e-05  6.57639992e-05
#   3.15645427e-05 -7.94102216e-04 -7.94102217e-04 -6.84367116e-04
#   1.79966197e-04  8.21372324e-02 -5.38343448e-02  8.96222991e-01
#  -2.41529627e-04  3.60687263e-01]

# %%
coeffecients = pd.DataFrame(lt.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#                 Coeffecient
# Lever position     0.001723
# Ship speed (v)     0.005670
# GTT                0.000014
# GTn                0.000066
# GGn                0.000032
# Ts                -0.000794
# Tp                -0.000794
# HP                -0.000684
# T2                 0.000180
# P48                0.082137
# P2                -0.053834
# Pexh               0.896223
# TIC               -0.000242
# mf                 0.360687

# %%
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, preds)))
print('R2 score:', metrics.r2_score(y_test, preds))
# Out:
# RMSE: 0.0022636094025611352
# R2 score: 0.9086685819640695

# %%
sns.set_style('darkgrid')
plt.scatter(y_test,preds)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
linear_Regression(X,y)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            Turbine DSC   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     9385.
# Date:                Sat, 13 Apr 2024   Prob (F-statistic):               0.00
# Time:                        03:39:49   Log-Likelihood:                 55892.
# No. Observations:               11934   AIC:                        -1.118e+05
# Df Residuals:                   11920   BIC:                        -1.117e+05
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.1430      0.072      1.987      0.047       0.002       0.284
# ...

# %%
#decision tree
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
from matplotlib import pyplot as plt

# Load the dataset
dataset = pd.read_csv('data1.csv')

# Split features and target variable
x = dataset.iloc[:, :18].astype(int)  # Assuming you want to select the first 18 columns for features
y = dataset.iloc[:, 18].astype(int)   # Assuming the target column is the 19th column

# Split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# Define the parameter distributions for randomized search
param_dist = {
    'max_depth': [5, 10, 15, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'ccp_alpha': [0.0, 0.01, 0.1, 1.0]  # Regularization parameter
}

# Perform randomized search with cross-validation
random_search = RandomizedSearchCV(estimator=DecisionTreeRegressor(), param_distributions=param_dist, n_iter=100, cv=5, scoring='r2')
random_search.fit(x_train, y_train)

# Get the best estimator from randomized search
best_regressor = random_search.best_estimator_

# Make predictions on the testing set using the best estimator
y_pred = best_regressor.predict(x_test)

# Calculate evaluation metrics
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = metrics.mean_squared_error(y_test, y_pred, squared=False)
r2 = metrics.r2_score(y_test, y_pred)

# Print evaluation metrics
#print('Mean Absolute Error (MAE):', mae)
#print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R²) Score:', r2)

accuracy = best_regressor.score(x_test, y_test)
print('Accuracy:', accuracy)
# !pip install scikit-learn
from sklearn.tree import plot_tree

# Visualization of the decision tree
plt.figure(figsize=(9, 6))
plot_tree(best_regressor, filled=True, feature_names=x.columns)
plt.savefig("decision_tree_R_tuned.png")  # Save the decision tree plot as an image
plt.show()
# Out:
# Root Mean Squared Error (RMSE): 0.18103051969456088
# R-squared (R²) Score: 0.14518855443841716
# Accuracy: 0.14518855443841716
# ...

# %%
#Random Forest
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

dataset = pd.read_csv('data1.csv')
print(dataset)

x = dataset.iloc[:, :18]  # Assuming you want to select the first 18 columns for features
print(x)

y = dataset.iloc[:, 18]   # Assuming the target column is the 19th column
print(y)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)
regressor = RandomForestRegressor(n_estimators=10)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

# Print true and predicted values
print("True values:", y_test.values)
print("Predicted values:", y_pred)

# Calculate and print evaluation metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred, squared=False))
print('R-squared Score:', metrics.r2_score(y_test, y_pred))

accuracy = regressor.score(x_test, y_test)
print('Accuracy:', accuracy)
# Visualization of individual trees (optional)
from matplotlib import pyplot as plt
from sklearn.tree import plot_tree

# Plot the first tree in the forest
plt.figure(figsize=(10, 10))
plot_tree(regressor.estimators_[0], filled=True)
plt.savefig("random_forest.png")
plt.show()
# Out:
#        index  Lever position   Ship speed (v)   \
# 0          0            1.138                3
# 1          1            2.088                6
# 2          2            3.144                9
# 3          3            4.161               12
# 4          4            5.140               15
# ...      ...              ...              ...
# 11929  11929            5.140               15
# 11930  11930            6.175               18
# 11931  11931            7.148               21
# 11932  11932            8.206               24
# 11933  11933            9.300               27
#
#        Gas Turbine (GT) shaft torque (GTT) [kN m]    \
# 0                                           289.964
# 1                                          6960.180
# 2                                          8379.229
# 3                                         14724.395
# 4                                         21636.432
# ...                                             ...
# ...
